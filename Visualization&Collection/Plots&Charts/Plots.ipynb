# %% [markdown]
# # Plots in Python with Matplotlib

# %% [markdown]
# Before we create Plots to find insights and patters, Like the machine learning models we first need to see the Data for analise, clean it and explore the columns, what the columns means and what is the important or importants Labels and/or scale the data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly as pt

# %%
df = pd.read_csv('user_behavior_dataset.csv', index_col=0)#data from https://www.kaggle.com/datasets/valakhorasani/mobile-device-usage-and-user-behavior-dataset

# %%
df
# Out:
#                Device Model Operating System  App Usage Time (min/day)  \
# User ID
# 1            Google Pixel 5          Android                       393
# 2                 OnePlus 9          Android                       268
# 3              Xiaomi Mi 11          Android                       154
# 4            Google Pixel 5          Android                       239
# 5                 iPhone 12              iOS                       187
# ...                     ...              ...                       ...
# 696               iPhone 12              iOS                        92
# 697            Xiaomi Mi 11          Android                       316
# 698          Google Pixel 5          Android                        99
# 699      Samsung Galaxy S21          Android                        62
# 700               OnePlus 9          Android                       212
#
#          Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# User ID
# ...

# %% [markdown]
# Let's check what the labels means:
#
# - User ID: Unique identifier for each user.
# - Device Model: Model of the user's smartphone.
# - Operating System: The OS of the device (iOS or Android).
# - App Usage Time: Daily time spent on mobile applications, measured in minutes.
# - Screen On Time: Average hours per day the screen is active.
# - Battery Drain: Daily battery consumption in mAh.
# - Number of Apps Installed: Total apps available on the device.
# - Data Usage: Daily mobile data consumption in megabytes.
# - Age: Age of the user.
# - Gender: Gender of the user (Male or Female).
# - User Behavior Class: Classification of user behavior based on usage patterns (1 to 5).

# %%
df.describe()
# Out:
#        App Usage Time (min/day)  Screen On Time (hours/day)  \
# count                700.000000                  700.000000
# mean                 271.128571                    5.272714
# std                  177.199484                    3.068584
# min                   30.000000                    1.000000
# 25%                  113.250000                    2.500000
# 50%                  227.500000                    4.900000
# 75%                  434.250000                    7.400000
# max                  598.000000                   12.000000
#
#        Battery Drain (mAh/day)  Number of Apps Installed  Data Usage (MB/day)  \
# count               700.000000                700.000000           700.000000
# mean               1525.158571                 50.681429           929.742857
# std                 819.136414                 26.943324           640.451729
# min                 302.000000                 10.000000           102.000000
# ...

# %% [markdown]
# In the machine learning module we already seen some Plots but now we'll go deeper into this Plots and Charts

# %% [markdown]
# # Scatter Plot:

# %% [markdown]
# ### we define X and Y just like machine learning but in this case X would be just one column
# ## Let's make an example using screen time and battery drain columns

# %%
x = df['Battery Drain (mAh/day)']
y = df['Screen On Time (hours/day)']

plt.scatter(x, y)
plt.show() # this method is to see the graph

# %% [markdown]
# Now we add some methos to improve our graph visualize

# %%
x = df['Battery Drain (mAh/day)']
y = df['Screen On Time (hours/day)']

plt.title('Screen Time & batery Drain Graph')
plt.xlabel('Battery Drain(mAh/day')
plt.ylabel('Screen On Time(hours/day)')
plt.scatter(x, y, color='red')
plt.show()

# %% [markdown]
# Let's see with others values

# %%
x = df['Number of Apps Installed']
y = df['App Usage Time (min/day)']

plt.title('Relation between App usage and Number of apps installed')
plt.xlabel('Number of Apps installed')
plt.ylabel('Total Apps Usage Time (min/day)')
plt.scatter(x, y, color='blue')
plt.show()

# %%
x = df['Number of Apps Installed']
y = df['Data Usage (MB/day)']

plt.title('Number of Apss Installed and Data usage')
plt.xlabel('Number of Apps installed')
plt.ylabel('Data Usage (MB/day)')
plt.scatter(x, y, color='purple')
plt.show()

# %% [markdown]
# ## Also we can make a way to do this more compact and organized using subplots():

# %%
fig, ax = plt.subplots(
    figsize=(7,7), nrows=2, ncols=2
)
fig.suptitle('Users behavior')

total_ax = [0,1,2,3]
colors=['red','green','blue','purple']

ax = fig.axes[total_ax[0]]
ax.set_xlabel('Battery Drain (mAh/day)')
ax.set_ylabel('Screen On Time (Hours/day)')
ax.scatter(df['Battery Drain (mAh/day)'], df['Screen On Time (hours/day)'], color=colors[0], marker='+', linewidths=1)


ax = fig.axes[total_ax[1]]
ax.set_xlabel('Number of Apps Installed')
ax.set_ylabel('Screen On Time (Hours/day)')
ax.scatter(df['Number of Apps Installed'], df['Screen On Time (hours/day)'], color=colors[1], marker='.')


ax = fig.axes[total_ax[2]]
ax.set_xlabel('Number of Apps Installed')
ax.set_ylabel('App Usage Time (min/day)')
ax.scatter(df['Number of Apps Installed'], df['App Usage Time (min/day)'], color=colors[2], marker='o')


ax = fig.axes[total_ax[3]]
ax.set_xlabel('Number of Apps Installed')
ax.set_ylabel('Data Usage (MB/day)')
ax.scatter(df['Number of Apps Installed'], df['Data Usage (MB/day)'], color=colors[3], marker='x')

# %% [markdown]
# # Bar Plots:

# %%
df2 = pd.read_csv('gym_members_exercise_tracking.csv') # data from: https://www.kaggle.com/datasets/valakhorasani/gym-members-exercise-dataset
df2.head()
# Out:
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   56    Male         88.3        1.71      180      157           60
# 1   46  Female         74.9        1.53      179      151           66
# 2   32  Female         68.1        1.66      167      122           54
# 3   25    Male         53.2        1.70      190      164           56
# 4   38    Male         46.1        1.79      188      158           68
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.69           1313.0         Yoga            12.6
# 1                      1.30            883.0         HIIT            33.9
# 2                      1.11            677.0       Cardio            33.4
# 3                      0.59            532.0     Strength            28.8
# 4                      0.64            556.0     Strength            29.2
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# ...

# %%
plt.title('Max calories burned in each exercise')
plt.ylabel('Calories')
plt.bar(df2['Workout_Type'], df2['Calories_Burned'], color='orange')
# Out:
# <BarContainer object of 973 artists>

# %% [markdown]
# # Pie Charts:

# %%
df = pd.read_csv('user_behavior_dataset.csv', index_col=0)
df_filtred = df[df['User Behavior Class'] > 3]
filter=df_filtred['Device Model'].unique()

x = []
for v in filter:
    df_for = df_filtred[df_filtred['Device Model'] == v]
    x.append(df_for['Device Model'].count())

x
# Out:
# [51, 56, 52, 60, 56]

# %%
plt.title('percentage of users')
plt.pie(x, labels=filter, autopct='%.2f%%', explode=[0.05,0.01,0.1,0.2,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x75674461e530>,
# ...
#  [Text(0.960275878833763, 0.6327481620123795, 'Google Pixel 5'),
#   Text(-0.2575828212740595, 1.0796995369937399, 'Samsung Galaxy S21'),
#   Text(-1.1936629377138948, 0.1231616463361666, 'OnePlus 9'),
#   Text(-0.4992030385777989, -1.2003317567550618, 'iPhone 12'),
#   Text(0.8824744584053272, -0.6566877722801184, 'Xiaomi Mi 11')],
#  [Text(0.5427646271669094, 0.3576402654852579, '18.55%'),
#   Text(-0.14155452340286154, 0.5933483942037667, '20.36%'),
#   Text(-0.6963033803331051, 0.07184429369609717, '18.91%'),
#   Text(-0.3072018698940301, -0.7386656964646534, '21.82%'),
#   Text(0.48134970458472387, -0.35819333033461, '20.36%')])

# %% [markdown]
# # Line plots:

# %%
df = pd.read_csv('netflix_titles.csv') # data from: https://www.kaggle.com/datasets/shivamb/netflix-shows
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
years = df['release_year'].unique()
counts = []
for y in range(0, len(years)):
    count_year = df[df['release_year'] == years[y]]
    counts.append(count_year.count().max())
df_count_years = pd.DataFrame({'Year': years,
                              'Number_of_movies': counts})
df_count_years.sort_values(ascending=True, by='Year', inplace=True)

# %%
plt.title('Number of movies throught the years')
plt.plot(df_count_years['Year'], df_count_years['Number_of_movies'], linestyle='--', color='black')

# %% [markdown]
# # Histograms:

# %%
df = pd.read_csv('gym_members_exercise_tracking.csv')
df.head()
# Out:
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   56    Male         88.3        1.71      180      157           60
# 1   46  Female         74.9        1.53      179      151           66
# 2   32  Female         68.1        1.66      167      122           54
# 3   25    Male         53.2        1.70      190      164           56
# 4   38    Male         46.1        1.79      188      158           68
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      1.69           1313.0         Yoga            12.6
# 1                      1.30            883.0         HIIT            33.9
# 2                      1.11            677.0       Cardio            33.4
# 3                      0.59            532.0     Strength            28.8
# 4                      0.64            556.0     Strength            29.2
#
#    Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# ...

# %%
plt.hist(df['BMI'], bins=20, color='pink')
# Out:
# (array([ 21.,  50.,  72.,  88.,  91., 115., 129., 105.,  80.,  70.,  43.,
#          36.,  20.,  12.,  12.,   9.,   6.,   8.,   4.,   2.]),
#  array([12.32 , 14.196, 16.072, 17.948, 19.824, 21.7  , 23.576, 25.452,
#         27.328, 29.204, 31.08 , 32.956, 34.832, 36.708, 38.584, 40.46 ,
#         42.336, 44.212, 46.088, 47.964, 49.84 ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# # Box plot:

# %%
df_male = df[df['Gender'] == 'Male']
df_female = df[df['Gender'] == 'Female']
plt.ylabel('Height (meters)')
plt.boxplot([df_male['Height (m)'], df_female['Height (m)']], labels=['Male Height AVG', 'Womas Height AVG'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7566d45c6710>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7566d45c6c50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7566d45c6470>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7566d45c7190>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7566d45c7430>,
# ...
#  'means': []}

# %% [markdown]
# # 3D Plots:

# %%
ax = plt.axes(projection='3d')
x = df['BMI']
y = df['Age']
z = df['Fat_Percentage']
ax.scatter(x,y,z, color='cyan', marker='+')
ax.set_xlabel('BMI')
ax.set_ylabel('Age')
ax.set_title('3d_plot | BMI, Age, Fat% relation')
# Out:
# Text(0.5, 0.92, '3d_plot | BMI, Age, Fat% relation')

# %%
ax = plt.axes(projection='3d')

x = np.arange(-5,5,0.1)
y = np.arange(-5,5,0.1)

X, Y = np.meshgrid(x, y)

Z = np.sin(X) * np.cos(Y)

ax.plot_surface(X, Y, Z, cmap='Spectral')

# %% [markdown]
# # Custom plots:

# %%
df = pd.read_csv('disney_movies_total_gross.csv') # data from: https://www.kaggle.com/datasets/rashikrahmanpritom/disney-movies-19372016-total-gross
df['release_date'] = pd.to_datetime(df['release_date'])
df.dropna(inplace=True)
df
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 0    Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                          Pinocchio   1940-02-09  Adventure           G
# 2                           Fantasia   1940-11-13    Musical           G
# 3                  Song of the South   1946-11-12  Adventure           G
# 4                         Cinderella   1950-02-15      Drama           G
# ..                               ...          ...        ...         ...
# 574         The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                   Queen of Katwe   2016-09-23      Drama          PG
# 576                   Doctor Strange   2016-11-04  Adventure       PG-13
# 577                            Moana   2016-11-23  Adventure          PG
# 578     Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 0      184925485                5228953251
# ...

# %%
df.describe()
# Out:
#                         release_date   total_gross  inflation_adjusted_gross
# count                            513  5.130000e+02              5.130000e+02
# mean   2000-04-23 02:09:07.368420992  7.130851e+07              1.275941e+08
# min              1937-12-21 00:00:00  2.815000e+03              2.984000e+03
# 25%              1994-10-21 00:00:00  1.628987e+07              2.624856e+07
# 50%              1999-12-24 00:00:00  3.817468e+07              5.967913e+07
# 75%              2007-01-12 00:00:00  8.450012e+07              1.291642e+08
# max              2016-12-16 00:00:00  9.366622e+08              5.228953e+09
# std                              NaN  9.677091e+07              3.014755e+08

# %%
df['inflation_adjusted_gross'] = df['inflation_adjusted_gross'] // 1000000
df['inflation_adjusted_gross']
# Out:
# 0      5228
# 1      2188
# 2      2187
# 3      1078
# 4       920
#        ...
# 574      12
# 575       8
# 576     232
# 577     246
# 578     529
# Name: inflation_adjusted_gross, Length: 513, dtype: int64

# %%
df.describe()
# Out:
#                         release_date   total_gross  inflation_adjusted_gross
# count                            513  5.130000e+02                513.000000
# mean   2000-04-23 02:09:07.368420992  7.130851e+07                127.103314
# min              1937-12-21 00:00:00  2.815000e+03                  0.000000
# 25%              1994-10-21 00:00:00  1.628987e+07                 26.000000
# 50%              1999-12-24 00:00:00  3.817468e+07                 59.000000
# 75%              2007-01-12 00:00:00  8.450012e+07                129.000000
# max              2016-12-16 00:00:00  9.366622e+08               5228.000000
# std                              NaN  9.677091e+07                301.476877

# %%
df = pd.read_csv('disney_movies_total_gross.csv') # data from: https://www.kaggle.com/datasets/rashikrahmanpritom/disney-movies-19372016-total-gross
df['release_date'] = pd.to_datetime(df['release_date'])
df.dropna(inplace=True)

df['inflation_adjusted_gross'] = df['inflation_adjusted_gross'] // 1000000
df['inflation_adjusted_gross']

income_labels = list(range(0, 6000, 400))
plt.yticks(income_labels, [f'{x}m $' for x in income_labels])
plt.title('Disney gross movies (inflation adjusted) in USD', fontsize=20)
plt.xlabel('years')
plt.plot(df['release_date'].head(10), df['inflation_adjusted_gross'].head(10), c='green')

# %%
income_labels = list(range(0, 1000, 50))
plt.yticks(income_labels, [f'{x}m $' for x in income_labels])
plt.title('Disney gross movies (inflation adjusted) in USD', fontsize=20)
plt.xlabel('years')
plt.plot(df['release_date'].tail(100), df['inflation_adjusted_gross'].tail(100), c='red')

# %% [markdown]
# ***

# %%
df = pd.read_csv('gym_members_exercise_tracking.csv')
df['Workout_Type'].unique()
df
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
mtx = []
for x in range(0, len(df['Workout_Type'].unique())):
    df_workout = df[df['Workout_Type'] == df['Workout_Type'].unique()[x]]
    mtx.append(df_workout['BMI'].head(50))

# %%
plt.plot(mtx[0], label='Yoga')
plt.plot(mtx[1], label='HIIT')
plt.plot(mtx[2], label='Cardio')
plt.plot(mtx[3], label='Strengh')
plt.legend()

# %%
df = pd.read_csv('user_behavior_dataset.csv', index_col=0)
df_filtred = df[df['User Behavior Class'] > 3]
filter=df_filtred['Device Model'].unique()

x = []
for v in filter:
    df_for = df_filtred[df_filtred['Device Model'] == v]
    x.append(df_for['Device Model'].count())

plt.figure(figsize=(10,7))
plt.title('percentage of users')
plt.pie(x, labels=None, autopct='%.2f%%', explode=[0.05,0.01,0.1,0.2,0])
plt.legend(labels=filter)

# %% [markdown]
# # Plot Styling:

# %%
# link to matplotlib styles: https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html

# %%
df = pd.read_csv('user_behavior_dataset.csv', index_col=0)
df_filtred = df[df['User Behavior Class'] > 3]
filter=df_filtred['Device Model'].unique()

x = []
for v in filter:
    df_for = df_filtred[df_filtred['Device Model'] == v]
    x.append(df_for['Device Model'].count())
plt.style.use('ggplot')
plt.figure(figsize=(10,7))
plt.title('percentage of users')
plt.pie(x, labels=None, autopct='%.2f%%', explode=[0.05,0.01,0.1,0.2,0])
plt.legend(labels=filter)

# %%
df = pd.read_csv('disney_movies_total_gross.csv')
df['release_date'] = pd.to_datetime(df['release_date'])
df.dropna(inplace=True)

df['inflation_adjusted_gross'] = df['inflation_adjusted_gross'] // 1000000
df['inflation_adjusted_gross']

income_labels = list(range(0, 6000, 400))
plt.style.use('classic')
plt.yticks(income_labels, [f'{x}m $' for x in income_labels])
plt.title('Disney gross movies (inflation adjusted) in USD', fontsize=20)
plt.xlabel('years')
plt.plot(df['release_date'].head(10), df['inflation_adjusted_gross'].head(10), c='green')

# %%
df = pd.read_csv('weight-height.csv') # data from: https://www.kaggle.com/datasets/mustafaali96/weight-height
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
plt.figure(figsize=(8,7))
plt.title('Heights and Weights from Males and Females')
plt.xlabel('Weight (lb)')
plt.ylabel('Height (inch)')
plt.style.use('dark_background')
plt.yticks(range(50,100, 2), [f'{x} inch.' for x in range(50,100, 2)])
for gender in df['Gender'].unique():
    subset = df[df['Gender']==gender]
    
    colors='pink'
    if gender == 'Male':
        colors= 'red'

    plt.scatter(subset['Weight'], subset['Height'], c=colors, alpha=0.2)
plt.legend(labels=['Male', 'Female'])

# %% [markdown]
# # Mixing Figures:

# %%
plt.style.use('dark_background')
fig, ax = plt.subplots(
    figsize=(17,17), nrows=2, ncols=2
)
fig.suptitle('Mix')


total_ax = [0,1,2,3]


ax = fig.axes[total_ax[0]]
df = pd.read_csv('weight-height.csv') # data from: https://www.kaggle.com/datasets/mustafaali96/weight-height
ax.set_yticks(range(50,100, 2), [f'{x} inch.' for x in range(50,100, 2)])
ax.set_xticks(range(50, 300, 20), [f'{x} lb.' for x in range(50,300,20)])
for gender in df['Gender'].unique():
    subset = df[df['Gender']==gender]    
    colors='pink'
    if gender == 'Male':
        colors= 'red'
    ax.scatter(subset['Weight'], subset['Height'], c=colors, alpha=0.2)
ax.legend(labels=['Male', 'Female'])


ax = fig.axes[total_ax[1]]
df = pd.read_csv('disney_movies_total_gross.csv')
df['release_date'] = pd.to_datetime(df['release_date'])
df.dropna(inplace=True)
df['inflation_adjusted_gross'] = df['inflation_adjusted_gross'] // 1000000
df['inflation_adjusted_gross']
income_labels = list(range(0, 6000, 400))
ax.set_yticks(income_labels, [f'{x}m $' for x in income_labels])
ax.set_xlabel('years')
ax.plot(df['release_date'].head(10), df['inflation_adjusted_gross'].head(10), c='green')
ax.legend(labels=['Disney'])


ax = fig.axes[total_ax[2]]
df = pd.read_csv('user_behavior_dataset.csv', index_col=0)
df_filtred = df[df['User Behavior Class'] > 3]
filter=df_filtred['Device Model'].unique()
x = []
for v in filter:
    df_for = df_filtred[df_filtred['Device Model'] == v]
    x.append(df_for['Device Model'].count())
ax.pie(x, labels=None, autopct='%.2f%%', explode=[0.05,0.01,0.1,0.2,0])
ax.legend(labels=filter)


ax = fig.axes[total_ax[3]]
df = pd.read_csv('gym_members_exercise_tracking.csv')
ax.hist(df['BMI'], bins=20, color='purple')
ax.legend(labels=['BMI'])
